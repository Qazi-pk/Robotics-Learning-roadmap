# %% [markdown]
# # 6_Computer_Vision_Part1_TensorIntro
#
# This is a placeholder notebook for 6_Computer_Vision_Part1_TensorIntro. You can add explanations, derivations, and exercises here.

# %%
# Python code goes here
print('Hello from 6_Computer_Vision_Part1_TensorIntro')
