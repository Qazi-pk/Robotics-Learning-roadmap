# %% [markdown]
# # 1_Kinematics_Part2_CoordinateFrames
#
# This is a placeholder notebook for 1_Kinematics_Part2_CoordinateFrames. You can add explanations, derivations, and exercises here.

# %%
# Python code goes here
print('Hello from 1_Kinematics_Part2_CoordinateFrames')
