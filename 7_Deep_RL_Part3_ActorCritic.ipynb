# %% [markdown]
# # 7_Deep_RL_Part3_ActorCritic
#
# This is a placeholder notebook for 7_Deep_RL_Part3_ActorCritic. You can add explanations, derivations, and exercises here.

# %%
# Python code goes here
print('Hello from 7_Deep_RL_Part3_ActorCritic')
