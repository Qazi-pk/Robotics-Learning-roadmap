# %% [markdown]
# # 9_Capstone_Part1_ProjectSetup
#
# This is a placeholder notebook for 9_Capstone_Part1_ProjectSetup. You can add explanations, derivations, and exercises here.

# %%
# Python code goes here
print('Hello from 9_Capstone_Part1_ProjectSetup')
