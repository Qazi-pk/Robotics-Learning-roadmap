# %% [markdown]
# # 8_Simulation_Part1_PyBulletBasics
#
# This is a placeholder notebook for 8_Simulation_Part1_PyBulletBasics. You can add explanations, derivations, and exercises here.

# %%
# Python code goes here
print('Hello from 8_Simulation_Part1_PyBulletBasics')
